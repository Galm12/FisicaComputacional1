# %%
import numpy as np

# %%
import pylab as pl

# %% [markdown]
# **Ejercicio 1.** Se proporciona el siguiente programa para calcular el área de un rectángulo:
#
# ***Ejemplo***
#
# Usando este ejemplo, modifícalo para calcular:
#
# area de: un círculo y  una elipse.
# volumen de: una esfera y el de un cilindro circular.
# Antes de cada celda donde se calcule un área o volumen, inserte una descripción de lo que se hace, utilizando notación Latex para las ecuaciones o símbolos.

# %%
# Se utiliza el símbolo # para hacer comentarios.
# Se define una función de 2 variables para calcular el área.  
def area(x, y):
    return x*y

print("Proporciona el largo y altura del rectángulo: ", end="")
l = float(input())
w = float(input())
a = area(l, w)
# Imprime el valor del área en formato libre.
print("\nArea = ", a)
# Imprime el valor del área con 2 decimales. 
print("\nArea = {:.2f}".format(a))
# Out:
# Proporciona el largo y altura del rectángulo: 1
# 1
#
# Area =  1.0
#
# Area = 1.00

# %%
def area(x, y):
    return (np.pi)*(y**2)
print("Para obtener el área de un circulo")
print("Proporciona el radio: ")
w = float(input())
a = area(l,w)
# Imprime el valor del área en formato libre.
print("\nArea = ", a)
# Out:
# Proporciona el radio del circulo:
# 2
#
# Area =  12.566370614359172

# %%
def area(x, y):
    return (np.pi)*y*x
print("Para obtener el área de una elipse")
print("Proporciona eje mayor y el eje menor: ")
l = float(input())
w = float(input())
a = area(l,w)
# Imprime el valor del área en formato libre.
print("\nArea = ", a)
# Out:
# Para obtener el área de una elipse
# Proporciona eje mayor y el eje menor:
# 1
# 2
#
# Area =  6.283185307179586

# %%
def area(x, y):
    return (0.75)*(np.pi)*(y**3) 
print("Para obtener el volumen de una esfera")
print("Proporciona radio: ")
w = float(input())
a = area(l,w)
# Imprime el valor del área en formato libre.
print("\nArea = ", a)
# Out:
# Para obtener el volumen de una esfera
# Proporciona radio:
# 2
#
# Area =  18.84955592153876

# %%
def area(x, y):
    return (np.pi)*(x**2)*(y)
print("Para obtener el volumen de un cilíndro circular")
print("Proporciona el radio y la altura: ")
l = float(input())
w = float(input())
a = area(l,w)
# Imprime el valor del área en formato libre.
print("\nArea = ", a)
# Out:
# Para obtener el volumen de un cilíndro circular
# Proporciona el radio y la altura:
# 2
# 3
#
# Area =  37.69911184307752

# %% [markdown]
# **Ejercicio 2.** Desarrollar un programa en Python que calcule las raíces de una ecuación cuadrática.

# %%
print("Calcularesmos las raíces de una ecuación cuadrática, para eso:")
#Pedimos los terminos de la ecuación
a= int(input("Ingresa el termino cuadrático\n"))
b= int(input("Ingresa el termino lineal\n"))
c= int(input("Ingrese el término independiente\n"))
x1=0
x2=0
#En caso de que la raíz sea negativa imprimimos esto
if ((b**2)-4*a*c) <0: 
        print("La solución a la ecuación cuadrática tiene resultados complejos")
#Damos los 2 valores de la ecuación
else:
  x1 = ((-b+np.sqrt((b**2)-4*a*c))/(2*a))
  x2 = ((-b-np.sqrt((b**2)-4*a*c))/(2*a))
  print("Estos son los valores reales a la ecuación cuadrática")
  print("Valor con signo positivo",x1)
  print("valor con signo negativo",x2)
# Out:
# Calcularesmos las raíces de una ecuación cuadrática, para eso:
# Ingresa el termino cuadrático
# 1
# Ingresa el termino lineal
# 10
# Ingrese el término independiente
# 1
# Estos son los valores reales a la ecuación cuadrática
# Valor con signo positivo -0.10102051443364424
# valor con signo negativo -9.898979485566356

# %% [markdown]
# **Ejercicio 3.** Implementar el método Babilonio (o Método de Herón), para calcular la raíz cuadrada de un número S, cuando la sucesión converja con un error menor a 0.01. Compare con el valor obtenido por el método Babilonio con el valor de la función np.sqrt(S).10
#
#  ![Actividad 3 imagen.jpg](data:image/jpeg;base64,...)

# %%
print("Ingresa un valor para obtener su raíz mediante el método Babilonio")
s = float(input())

def babilonio(s):
#Defínimos 2 casos hipoteticos donde la raíz puede ser 0 o ser compleja
    if s == 0:
       return print ( "La raíz vale 0" )

    if s < 0:
       return print ( "La raíz no tiene un valor complejo" )
#Utilizamos un bucle para acercar el valor a la raíz, el bucle cierra cuando el error sea menor a 0.001   
    else:
         x = 2
         y = (x + (s/x)) / 2
         while abs((s/x) - y) > 0.001:
                x = y
                y = (x + (s / x)) / 2
         return y
#Print los valores obtenidos
print(" ")
print("valor de raiz por el  método Babilonio", babilonio(s))
print(" ")
print("valor exacto de la raiz", np.sqrt(s))
# Out:
# Ingresa un valor para obtener su raíz mediante el método Babilonio
# 1
#
# valor de raiz por el  método Babilonio 1.0000000464611474
#
# valor exacto de la raiz 1.0

# %% [markdown]
# **Ejercicio 4.**  Reproduce la figura que aparece inmediatamente abajo en el artículo de Wikipedia sobre Series de Taylor, que muestra la aproximación de la función ln(1+x) alrededor de x=0.
# ![Ejercicio 4 taylor.jpg](data:image/jpeg;base64,...)![Ejercicio 4 gráfica.jpg](data:image/jpeg;base64,...)
#
# Se observa que a medida que se usa una aproximación de orden mayor de la Serie de Taylor, la aproximación no es tan buena.

# %%
#Definimos los puntos de la funciones
x1, Y1 = (x), np.log(1+x)
x2, Y2 = (x), (x-((x**2)/2)+((x**3)/3)-((x**4)/4))
x3, Y3 = (x), (x-((x**2)/2)+((x**3)/3)-((x**4)/4)+((x**5)/5)-((x**6)/6)+((x**7)/7))
x4, Y4 = (x), (x-((x**2)/2)+((x**3)/3)-((x**4)/4)+((x**5)/5)-((x**6)/6)+((x**7)/7)-((x**8)/8)+((x**9)/9)-((x**10)/10)+((x**11)/11))
x5, Y5 = (x), (x-((x**2)/2)+((x**3)/3)-((x**4)/4)+((x**5)/5)-((x**6)/6)+((x**7)/7)-((x**8)/8)+((x**9)/9)-((x**10)/10)+((x**11)/11)-((x**12)/12)+((x**13)/13)-((x**14)/14)+((x**15)/15)-((x**16)/16))

#Usamos pl.plot para graficar los puntos de las funciones anteriores
pl.plot(x1, Y1)
pl.plot(x2, Y2)
pl.plot(x3, Y3)
pl.plot(x4, Y4)
pl.plot(x5, Y5)

#Definimos el tamaño de la gráfica y colocamos una malla
pl.ylim(-4,2)
pl.xlim(-1.5,1.5)
pl.grid(True)
pl.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
